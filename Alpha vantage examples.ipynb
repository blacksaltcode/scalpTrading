# %%
# !pip install alpha_vantage

# %matplotlib inline
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from alpha_vantage.sectorperformance import SectorPerformances
from alpha_vantage.cryptocurrencies import CryptoCurrencies
import matplotlib
import matplotlib.pyplot as plt
import os
# Make plots bigger
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)
# Out:
# Collecting alpha_vantage
# Requirement already satisfied: requests in /Users/mukesh/anaconda3/lib/python3.7/site-packages (from alpha_vantage) (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/mukesh/anaconda3/lib/python3.7/site-packages (from requests->alpha_vantage) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/mukesh/anaconda3/lib/python3.7/site-packages (from requests->alpha_vantage) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mukesh/anaconda3/lib/python3.7/site-packages (from requests->alpha_vantage) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/mukesh/anaconda3/lib/python3.7/site-packages (from requests->alpha_vantage) (3.0.4)
# Installing collected packages: alpha-vantage
# Successfully installed alpha-vantage-2.1.0

# %% [markdown]
# # Working with time Series
# We first download the data with our api key.

# %%
ts = TimeSeries(key=os.environ['ALPHA_VANTAGE_API_KEY'], output_format='pandas')
data, meta_data = ts.get_intraday(symbol='NSE:HDFC',interval='1min', outputsize='full')
# We can describe it
data.describe()
# Out:
#            1. open      2. high       3. low     4. close     5. volume
# count  1864.000000  1864.000000  1864.000000  1864.000000  1.864000e+03
# mean   2147.876354  2148.867653  2146.923674  2147.864872  1.525883e+04
# std      28.009051    28.027947    28.014012    28.018404  7.793477e+04
# min    2083.350100  2084.149900  2083.000000  2083.000000  0.000000e+00
# 25%    2131.037500  2131.974975  2129.812575  2130.962500  5.628000e+03
# 50%    2150.399900  2151.300050  2149.700000  2150.349950  8.338500e+03
# 75%    2172.424925  2173.525025  2171.125075  2172.500000  1.336875e+04
# max    2192.078900  2194.036400  2189.899900  2192.000000  3.291299e+06

# %%
data.describe()
data['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.grid()
plt.show()

# %% [markdown]
# Check the meta data given back by the api call.

# %%
meta_data
# Out:
# {'1. Information': 'Intraday (1min) open, high, low, close prices and volume',
#  '2. Symbol': 'NSE:HDFC',
#  '3. Last Refreshed': '2019-09-03 05:59:00',
#  '4. Interval': '1min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}

# %% [markdown]
# ## Getting csv data

# %%
ts = TimeSeries(key=os.environ['API_KEY'], output_format='csv')
data_csv,_ = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='compact')
data_csv

# %% [markdown]
# ## Plotting time series

# %%
data = data.drop('5. volume',1)
data.plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.grid()
plt.show()

# %% [markdown]
# # Working with batch quotes

# %%
# It is still a TimeSeries call
ts.output_format='pandas'
data, meta_data = ts.get_batch_stock_quotes(symbols=('MSFT', 'FB', 'AAPL'))
data.describe()
# Out:
#        1. symbol  2. price 3. volume         4. timestamp
# count          3         3         3                    3
# unique         3         3         1                    2
# top           FB  172.0600        --  2018-01-03 15:59:58
# freq           1         1         3                    2

# %%
data.head(3)
# Out:
#      1. symbol  2. price 3. volume         4. timestamp
# date
# 0         MSFT   86.3000        --  2018-01-03 15:59:59
# 1           FB  184.4800        --  2018-01-03 15:59:58
# 2         AAPL  172.0600        --  2018-01-03 15:59:58

# %% [markdown]
# # Working with technical indicators

# %%
ti = TechIndicators(key=os.environ['API_KEY'], output_format='pandas')
data, meta_data = ti.get_bbands(symbol='MSFT', interval='60min', time_period=60)
data.describe()
# Out:
#        Real Middle Band  Real Upper Band  Real Lower Band
# count         11.000000        11.000000        11.000000
# mean          85.611645        86.214027        85.009273
# std            0.039812         0.096451         0.025967
# min           85.569100        86.103600        84.968900
# 25%           85.577450        86.117450        84.992700
# 50%           85.602800        86.206100        85.012300
# 75%           85.633200        86.295450        85.033200
# max           85.686500        86.355800        85.043200

# %%
meta_data
# Out:
# {'1: Symbol': 'MSFT',
#  '2: Indicator': 'Bollinger Bands (BBANDS)',
#  '3: Last Refreshed': '2018-01-03 16:00:00',
#  '4: Interval': '60min',
#  '5: Time Period': 60,
#  '6.1: Deviation multiplier for upper band': 2,
#  '6.2: Deviation multiplier for lower band': 2,
#  '6.3: MA Type': 0,
#  '7: Series Type': 'close',
#  '8: Time Zone': 'US/Eastern Time'}

# %% [markdown]
# ## Plotting technical indicators

# %%
data.plot()
plt.title('BBbands indicator for  MSFT stock (60 min)')
plt.grid()
plt.show()

# %% [markdown]
# # Working with Sector Performance

# %%
sp = SectorPerformances(key=os.environ['API_KEY'], output_format='pandas')
data, meta_data = sp.get_sector()
data.describe()
# Out:
#        Rank A: Real-Time Performance  Rank B: Day Performance  \
# count                      11.000000                11.000000
# mean                        0.002745                 0.002745
# std                         0.010159                 0.010159
# min                        -0.021700                -0.021700
# 25%                         0.000200                 0.000200
# 50%                         0.005300                 0.005300
# 75%                         0.008550                 0.008550
# max                         0.015300                 0.015300
#
#        Rank C: Day Performance  Rank D: Month Performance  \
# count                11.000000                  11.000000
# mean                  0.007545                   0.020836
# std                   0.016407                   0.039578
# min                  -0.025600                  -0.075500
# 25%                  -0.002550                   0.013650
# 50%                   0.014100                   0.030700
# 75%                   0.019550                   0.043350
# max                   0.027000                   0.073800
#
#        Rank E: Month Performance  Rank F: Year-to-Date (YTD) Performance  \
# count                  11.000000                               11.000000
# mean                    0.055373                                0.008600
# std                     0.044700                                0.018032
# min                    -0.024300                               -0.019500
# 25%                     0.022900                               -0.005500
# 50%                     0.061400                                0.012900
# 75%                     0.082400                                0.022400
# max                     0.115100                                0.033400
#
#        Rank G: Year Performance  Rank H: Year Performance  \
# count                 11.000000                 10.000000
# mean                   0.151027                  0.253480
# std                    0.135972                  0.203729
# min                   -0.078000                 -0.064300
# 25%                    0.066000                  0.110000
# 50%                    0.200600                  0.248300
# 75%                    0.231950                  0.381075
# max                    0.403500                  0.641300
#
#        Rank I: Year Performance  Rank J: Year Performance
# count                 10.000000                 10.000000
# mean                   0.721240                  0.805070
# std                    0.453161                  0.779563
# min                    0.010700                 -0.091600
# 25%                    0.484750                  0.222725
# 50%                    0.756500                  0.679850
# 75%                    1.066825                  1.298925
# max                    1.370300                  2.153500

# %%
meta_data
# Out:
# {'Information': 'US Sector Performance (realtime & historical)',
#  'Last Refreshed': '04:20 PM ET 01/03/2018'}

# %% [markdown]
# ## Plotting Sector Performance

# %%
data['Rank A: Real-Time Performance'].plot(kind='bar')
plt.title('Real Time Performance (%) per Sector')
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# # Working with Crypto Currencies

# %% [markdown]
# To just get the current exchange rate

# %%
cc = CryptoCurrencies(key=os.environ['API_KEY'])

# %% [markdown]
# To get the intraday price of bitcoin

# %%
# I changed the internal format of the the class to be our friendly data frame.
cc.output_format='pandas'
data, meta_data = cc.get_digital_currency_intraday(symbol='BTC', market='CNY')
data.describe()
# Out:
#        1a. price (CNY)  1b. price (USD)   2. volume  3. market cap (USD)
# count       922.000000       922.000000  922.000000           922.000000
# mean      92991.062733     14300.945469    0.166866          2386.971637
# std        4394.086228       679.068238    0.023152           359.894840
# min       85534.210870     13142.529558    0.122420          1695.678448
# 25%       88542.864820     13607.126501    0.148940          2110.466381
# 50%       94697.432190     14587.462789    0.170690          2377.083164
# 75%       96798.409910     14888.627226    0.185670          2640.120143
# max       98548.361320     15159.653779    0.200390          2983.532010

# %%
data.head(5)
# Out:
#                      1a. price (CNY)  1b. price (USD)  2. volume  \
# date
# 2018-01-01 09:25:00      88187.41817     13507.550170    0.15565
# 2018-01-01 09:30:00      88187.41817     13507.550170    0.15565
# 2018-01-01 09:35:00      88187.41817     13553.116458    0.15565
# 2018-01-01 09:40:00      88187.41817     13553.116458    0.15565
# 2018-01-01 09:45:00      88542.86482     13607.743410    0.15975
#
#                      3. market cap (USD)
# date
# 2018-01-01 09:25:00          2102.450184
# 2018-01-01 09:30:00          2102.450184
# 2018-01-01 09:35:00          2109.542577
# 2018-01-01 09:40:00          2109.542577
# 2018-01-01 09:45:00          2173.837010

# %%
data['1b. price (USD)'].plot()
plt.tight_layout()
plt.title('Intraday value for bitcoin (BTC)')
plt.grid()
plt.show()
